# %% [markdown]
# ### import library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# Load data (Pastikan file Titanic-Dataset.csv berada di folder yang sama)
df = pd.read_csv('Titanic-Dataset.csv')

# %%
# Cek struktur data
print("Info data:")
print(df.info())

print("\nDeskripsi statistik:")
print(df.describe())
# Out:
# Info data:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB
# None
#
# Deskripsi statistik:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
# Visualisasi fitur penting (Distribusi Survival Umum)
sns.countplot(x='Survived', data=df)
plt.title("Distribusi Survival")
plt.show()

# %%
# Distribusi Survival berdasarkan Pclass
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title("Survival berdasarkan Pclass")
plt.show()

# %%
# Distribusi Survival berdasarkan Jenis Kelamin
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Survival berdasarkan Jenis Kelamin")
plt.show()

# %%
# Looping visualisasi Survival berdasarkan fitur kategori lainnya
kategori_cols = ['Sex', 'Pclass', 'Embarked']
for col in kategori_cols:
    sns.countplot(x=col, hue='Survived', data=df)
    plt.title(f"Survival berdasarkan {col}")
    plt.show()

# %%
# Boxplot Distribusi Umur per Kelas Penumpang
sns.boxplot(x="Pclass", y="Age", data=df)
plt.title("Distribusi Umur per Kelas Penumpang")
plt.xlabel("Kelas Penumpang")
plt.ylabel("Umur")
plt.show()

# %%
# Boxplot Distribusi Fare terhadap Keselamatan
sns.boxplot(x="Survived", y="Fare", data=df)
plt.title("Distribusi Fare terhadap Keselamatan")
plt.show()

# %%
# Boxplot Distribusi Umur Berdasarkan Jenis Kelamin dan Keselamatan
sns.boxplot(x="Sex", y="Age", hue="Survived", data=df)
plt.title("Distribusi Umur Berdasarkan Jenis Kelamin dan Keselamatan")
plt.xlabel("Jenis Kelamin")
plt.ylabel("Umur")
plt.show()

# %%
# Boxplot Distribusi PClass Berdasarkan Fare dan Keselamatan
sns.boxplot(x="Pclass", y="Fare", hue="Survived", data=df)
plt.title("Distribusi PClass Berdasarkan Fare dan Keselamatan")
plt.xlabel("Pclass")
plt.ylabel("Fare")
plt.show()

# %%
# Cek missing values
print("\nMissing values pada data:")
missing_values = df.isnull().sum()
missing_percent = (missing_values / len(df)) * 100
print("Jumlah Missing Values:\n", missing_values)
print("\nPersentase Missing Values:\n", missing_percent)

# %%
# Cek jumlah baris yang duplikat (Sintaks telah diperbaiki)
duplicate_rows = df.duplicated().sum()
print(f"\nJumlah baris duplikat: {duplicate_rows}")

# %%
# Looping visualisasi boxplot untuk melihat outlier pada fitur numerik
numerik_cols = ['Age', 'Fare', 'SibSp', 'Parch']
for col in numerik_cols:
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot: {col}")
    plt.show()
